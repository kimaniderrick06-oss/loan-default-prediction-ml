# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load dataset
df=pd.read_csv(r"C:\Users\LENOVO T480\Downloads\beginner_scikit_learn_loan_default.csv")

# %%
#check first few 10
df.head(10)
# Out:
#   customer_id  age  monthly_income_ksh  employment_years  credit_score  \
# 0   CUST10001   23            101577.0              17.2         567.0
# 1   CUST10002   49            107972.0               4.1         732.0
# 2   CUST10003   55             41551.0               3.5         672.0
# 3   CUST10004   59             66605.0               7.8         732.0
# 4   CUST10005   38             46412.0               4.7         589.0
# 5   CUST10006   40            184613.0               7.7         672.0
# 6   CUST10007   63            109897.0               2.1         751.0
# 7   CUST10008   43             30433.0               7.1         767.0
# 8   CUST10009   54             34657.0              14.6         699.0
# 9   CUST10010   53             36900.0              10.7         707.0
#
#    loan_amount_ksh  loan_term_months  existing_loans  late_payments_last_12m  \
# 0         128700.0                24               2                       0
# 1         109800.0                36               3                       1
# 2         245700.0                36               1                       0
# 3         159200.0                12               1                       5
# 4         178300.0                24               2                       0
# 5         109500.0                36               0                       0
# 6         201800.0                24               1                       0
# 7          96100.0                24               0                       0
# 8         310100.0                 6               0                       1
# 9         186400.0                24               0                       0
#
#    debt_to_income_ratio  savings_ksh  dependents employment_type  \
# 0                  0.64      22900.0           5        Salaried
# 1                  0.38      31300.0           3        Salaried
# 2                  0.29     108400.0           4        Salaried
# 3                  0.18      45200.0           4        Salaried
# 4                  0.33      69900.0           3        Salaried
# 5                  0.57     140000.0           1        Salaried
# 6                  0.58      54800.0           3   Self-employed
# 7                  0.26      56700.0           3        Salaried
# 8                  0.32      88800.0           4        Salaried
# 9                  0.29      82800.0           0   Self-employed
#
#   education_level housing_status  loan_default
# 0         Diploma           Rent             1
# 1          Degree         Family             1
# 2         Diploma            Own             0
# 3          Degree           Rent             1
# 4       Secondary         Family             1
# 5          Degree           Rent             1
# 6          Degree         Family             0
# 7         Diploma            NaN             0
# 8       Secondary            Own             1
# 9         Diploma            Own             1

# %%
#check dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             1212 non-null   object
#  1   age                     1212 non-null   int64
#  2   monthly_income_ksh      1188 non-null   float64
#  3   employment_years        1193 non-null   float64
#  4   credit_score            1194 non-null   float64
#  5   loan_amount_ksh         1212 non-null   float64
#  6   loan_term_months        1212 non-null   int64
#  7   existing_loans          1212 non-null   int64
#  8   late_payments_last_12m  1212 non-null   int64
#  9   debt_to_income_ratio    1212 non-null   float64
#  10  savings_ksh             1212 non-null   float64
#  11  dependents              1212 non-null   int64
#  12  employment_type         1212 non-null   object
#  13  education_level         1194 non-null   object
#  14  housing_status          1194 non-null   object
#  15  loan_default            1212 non-null   int64
# dtypes: float64(6), int64(6), object(4)
# memory usage: 151.6+ KB

# %%
#describe dataset
df.describe()
# Out:
#                age  monthly_income_ksh  employment_years  credit_score  \
# count  1212.000000         1188.000000       1193.000000   1194.000000
# mean     43.074257        66174.572391          7.384661    651.643216
# std      13.030020        31221.873328          4.663874     58.646254
# min      -2.000000        13857.000000          0.000000    -10.000000
# 25%      32.000000        43922.750000          3.800000    615.000000
# 50%      43.000000        59453.500000          7.400000    653.000000
# 75%      54.000000        82203.750000         10.700000    687.750000
# max      90.000000       287047.000000         24.400000    850.000000
#
#        loan_amount_ksh  loan_term_months  existing_loans  \
# count      1212.000000       1212.000000     1212.000000
# mean     183305.033003         22.178218        1.075083
# std       98679.062655         10.932172        1.029767
# min       33800.000000          6.000000        0.000000
# 25%      110575.000000         12.000000        0.000000
# 50%      164650.000000         24.000000        1.000000
# 75%      225750.000000         24.000000        2.000000
# max      782200.000000         48.000000        6.000000
#
#        late_payments_last_12m  debt_to_income_ratio   savings_ksh  \
# count             1212.000000           1212.000000  1.212000e+03
# mean                 0.868812              0.356205  1.091431e+05
# std                  0.956589              0.123721  1.120026e+05
# min                  0.000000             -0.100000  8.700000e+03
# 25%                  0.000000              0.280000  5.017500e+04
# 50%                  1.000000              0.360000  8.115000e+04
# 75%                  1.000000              0.430000  1.364000e+05
# max                  5.000000              1.500000  2.380000e+06
#
#         dependents  loan_default
# count  1212.000000   1212.000000
# mean      2.476073      0.629538
# std       1.699154      0.483128
# min       0.000000      0.000000
# 25%       1.000000      0.000000
# 50%       3.000000      1.000000
# 75%       4.000000      1.000000
# max       5.000000      1.000000

# %%
#check the sum of nulls
df.isnull().sum()
# Out:
# customer_id                0
# age                        0
# monthly_income_ksh        24
# employment_years          19
# credit_score              18
# loan_amount_ksh            0
# loan_term_months           0
# existing_loans             0
# late_payments_last_12m     0
# debt_to_income_ratio       0
# savings_ksh                0
# dependents                 0
# employment_type            0
# education_level           18
# housing_status            18
# loan_default               0
# dtype: int64

# %%
#check the shape
df.shape
# Out:
# (1212, 16)

# %%
#cleaning the dataset
#1. dropping duplicates
df=df.drop_duplicates()

# %%
#2.Removing unrealistic age values
df["age"].unique()
# Out:
# array([23, 49, 55, 59, 38, 40, 63, 43, 54, 53, 30, 46, 35, 57, 37, 25, 24,
#        41, 60, 28, 62, 56, 42, 51, 48, 33, 61, 26, 21, 32, 31, 34, 39, 36,
#        64, 65, 27, 47, 22, 58, 44, 50, 45, 17, 29, 52, -2, 90])

# %%
df=df[(df["age"])>0 & (df["age"]<=100)]

# %%
df["age"].unique()
# Out:
# array([23, 49, 55, 59, 38, 40, 63, 43, 54, 53, 30, 46, 35, 57, 37, 25, 24,
#        41, 60, 28, 62, 56, 42, 51, 48, 33, 61, 26, 21, 32, 31, 34, 39, 36,
#        64, 65, 27, 47, 22, 58, 44, 50, 45, 17, 29, 52, 90])

# %%
df.head()
# Out:
#   customer_id  age  monthly_income_ksh  employment_years  credit_score  \
# 0   CUST10001   23            101577.0              17.2         567.0
# 1   CUST10002   49            107972.0               4.1         732.0
# 2   CUST10003   55             41551.0               3.5         672.0
# 3   CUST10004   59             66605.0               7.8         732.0
# 4   CUST10005   38             46412.0               4.7         589.0
#
#    loan_amount_ksh  loan_term_months  existing_loans  late_payments_last_12m  \
# 0         128700.0                24               2                       0
# 1         109800.0                36               3                       1
# 2         245700.0                36               1                       0
# 3         159200.0                12               1                       5
# 4         178300.0                24               2                       0
#
#    debt_to_income_ratio  savings_ksh  dependents employment_type  \
# 0                  0.64      22900.0           5        Salaried
# 1                  0.38      31300.0           3        Salaried
# 2                  0.29     108400.0           4        Salaried
# 3                  0.18      45200.0           4        Salaried
# 4                  0.33      69900.0           3        Salaried
#
#   education_level housing_status  loan_default
# 0         Diploma           Rent             1
# 1          Degree         Family             1
# 2         Diploma            Own             0
# 3          Degree           Rent             1
# 4       Secondary         Family             1

# %%
#3.Standardising the "nan"
df["employment_years"]=df["employment_years"].replace({"nan":np.nan})
df["employment_years"].unique()
# Out:
# array([17.2,  4.1,  3.5,  7.8,  4.7,  7.7,  2.1,  7.1, 14.6, 10.7,  9.1,
#        13.8, 16.6,  0. , 10.4,  3.7,  nan,  1.7, 10.3,  8.6, 12.2, 17.4,
#        21.7,  0.6,  5.3,  4. , 10. ,  9.3,  9. , 11.1,  5. , 11.8,  8.7,
#         0.2,  1.1, 15.7,  6.9,  8. ,  8.9, 10.6,  1.8,  3. , 11.3,  6.3,
#        12.8, 12.9,  6.1,  6.4, 10.2, 10.5,  5.4,  6.6, 18.4,  9.2,  4.4,
#         3.1, 16.1, 13.5,  4.3,  5.9, 14.5,  9.9, 16.4, 14. ,  6.2,  7.3,
#         9.7,  0.4,  4.9, 13. , 18.2,  8.4,  4.8,  5.5,  7.4,  8.5,  3.9,
#         7. ,  0.7,  4.5, 14.2,  2. , 14.9, 10.8, 11. ,  7.5,  6.7, 14.7,
#         0.8, 10.9,  3.8,  1. ,  8.8,  7.2, 11.5, 15. , 18.6,  5.1, 15.4,
#         8.3, 15.6,  2.9,  6.8, 15.5,  6. ,  3.4, 19.5, 11.6, 13.9, 17.8,
#         9.4, 12.1,  0.1,  8.2,  4.2,  9.8,  7.9, 12.5,  0.5, 13.6, 13.1,
#        12.3,  9.6,  1.4,  2.4, 12.4,  2.3,  3.3,  7.6, 11.2, 15.3, 15.1,
#         2.6, 17.6, 11.4,  4.6,  6.5,  0.3,  3.6, 13.3, 15.2, 11.9,  2.7,
#         2.2,  8.1, 14.8, 11.7, 14.1,  9.5, 15.8,  5.7,  3.2,  1.9,  2.8,
#         5.2, 12.7, 10.1, 12. , 13.2,  5.8,  5.6, 18.8, 24.4, 16.2, 18.7,
#        21. ,  1.6, 15.9, 19.3,  1.2, 16. , 19.8, 13.4, 14.3, 17.5, 18.9,
#        12.6, 13.7,  1.5,  1.3, 20.3, 16.3, 17.7, 14.4, 19. ,  0.9, 21.6])

# %%
#4.Removing unrealistic credit_score values
df=df[(df["credit_score"])>0]

# %%
df.head()
# Out:
#   customer_id  age  monthly_income_ksh  employment_years  credit_score  \
# 0   CUST10001   23            101577.0              17.2         567.0
# 1   CUST10002   49            107972.0               4.1         732.0
# 2   CUST10003   55             41551.0               3.5         672.0
# 3   CUST10004   59             66605.0               7.8         732.0
# 4   CUST10005   38             46412.0               4.7         589.0
#
#    loan_amount_ksh  loan_term_months  existing_loans  late_payments_last_12m  \
#         78200., 161400., 270400., 103300., 111900., 118500.,  68300.,
#        273900., 102900.,  67300., 137200.,  87400., 175700., 119200.,
#        306400., 107400., 149800., 314400., 202200., 145300., 150500.,
#        122400., 132500., 173100., 288900., 289000., 190200., 103200.,
#         88100., 199100., 221700., 437600., 190500., 278900., 218300.,
#        265300., 246400., 236500., 153000., 309900., 155600.])

# %%
#5.Removing unrealistic values in debt_to_income_ratio
df=df[(df["debt_to_income_ratio"])>0.00]
df["debt_to_income_ratio"].unique()
# Out:
# array([0.64, 0.38, 0.29, 0.18, 0.33, 0.57, 0.58, 0.26, 0.32, 0.54, 0.37,
#        0.3 , 0.13, 0.31, 0.34, 0.41, 0.39, 0.12, 0.25, 0.6 , 0.44, 0.43,
#        0.23, 0.19, 0.52, 0.28, 0.27, 0.56, 0.42, 0.4 , 0.36, 0.5 , 0.47,
#        0.53, 0.46, 0.51, 0.22, 0.24, 0.35, 0.59, 0.16, 0.21, 0.49, 0.45,
#        0.55, 0.14, 0.7 , 0.48, 0.17, 0.2 , 0.05, 0.15, 0.61, 1.5 , 0.06,
#        0.1 , 0.65, 0.11, 0.69, 0.62, 0.67, 0.07, 0.68, 0.09, 0.63])

# %%
df["savings_ksh"].unique()
# Out:
# array([  22900.,   31300.,  108400.,   45200.,   69900.,  140000.,
#          54800.,   56700.,   88800.,   82800.,   62700.,   92500.,
#          91500.,  315700.,   38000.,  116500.,   42500.,   22800.,
#         103100.,   34100.,   77800.,  110800.,  204700.,   33600.,
#          55800.,  293700.,   96100.,  121000.,  566600.,   57600.,
#         143800.,  145400.,  128400.,   36600.,  217900.,  137900.,
#          91600.,   61000.,  241800.,   85900.,   72400.,  112100.,
#         182000.,  108600.,   75800.,   75900.,  163100.,   25500.,
#          65000.,  133300.,   35500.,   32300.,  238700.,   67100.,
#         185000.,   23000.,  429300.,   26800.,   60300.,  278700.,
#         163800.,  167700.,   70900.,   56300.,   53800.,  298800.,
#         152500.,   31400.,   39600.,  112500.,   65400.,  176100.,
#          32200.,   55100.,   89400.,   58900.,   63100.,  142100.,
#          75200.,   67800.,  358200.,   93200.,   53100.,  148600.,
#         300900.,   85500.,   95500.,   69800.,  104900.,  146000.,
#         179500.,   41200.,   24300.,   56100.,   34700.,   84000.,
#          36300.,  177300.,  147400.,   97200.,   29000.,   82400.,
#          89600.,   37600.,  308800.,  123900.,   87100.,   77000.,
#         101900.,   24200.,   44800.,   77300.,   39900.,   92400.,
#          67300.,  126200.,  134800.,  367800.,   87200.,  166900.,
#         471300.,   95200.,   94700.,  105300.,   28200.,  119100.,
#          68500.,  133000.,   70000.,  326900.,  194000.,   97300.,
#          42600.,   75300.,  128700.,   79500.,   81000.,   62500.,
#         190800.,   57200.,  150500.,   71100.,   48600.,   22300.,
#          38100.,   46400.,   49100.,   86600.,   93700.,   18900.,
#         185800.,   31900.,  127900.,   22100.,  106300.,   30400.,
#          56900.,   57500.,  111900.,  102000.,   37000.,  190200.,
#          34900.,  252900.,   78100.,   65500.,  108200.,  144700.,
#         115200.,  125000.,  117100.,  250700.,  225900.,   12900.,
#          93300.,   18500.,   32700.,   89300.,   27500.,  274800.,
#          47200.,   78700.,  106600.,   20100.,  188300.,  364700.,
#          58300.,  193600.,   31700.,  175700.,   50300.,   12200.,
#          66500.,   51800.,  117700.,  141600.,   41400.,  208800.,
#          53000.,  149300.,  149100.,  270500.,  206500.,   87500.,
#          95700.,  125100.,    8700.,  107100.,  199300.,   83100.,
#          11700.,  232900.,  153500.,   63200.,   12100.,  159000.,
#          58000.,  201400.,   21800.,  238800.,   82000.,   70400.,
#         183500.,   19800.,  127700.,   52000.,  100900.,   96800.,
#         418200.,  110700.,  100600.,  148500.,   40200.,   73800.,
#         146600.,  224600.,   15100.,   45500.,  105700.,   57000.,
#          83500.,  234700.,   94200.,  112300.,  151500.,  353700.,
#          49200.,  213900.,  279500.,  258700.,   68800.,  147900.,
#          92300.,  244200.,  199200.,   67900.,   28800.,  113500.,
#          37700.,   21400.,   51400.,  133600.,   37200.,   27600.,
#          35000.,   60200.,  154400.,  176700.,  256100.,  266200.,
#          81300.,   74600.,  359900.,  272600.,   34000.,   13700.,
#          42200.,  262100.,   83200.,   70200.,  134900.,   48800.,
#          72900.,   48300.,   30600.,   17900.,  218700.,  117400.,
#          15900.,   69700.,   43400.,  695900.,   82900.,  174300.,
#         122900.,  128600.,   89500.,   97100.,   31100.,   89700.,
#         518500.,  143500.,  246300.,   71200.,  211200.,  345900.,
#         172500.])

# %%
df["employment_type"].unique()
# Out:
# array(['Salaried', 'Self-employed', 'Business', 'Contract',
#        'SELF-EMPLOYED', ' salaried '], dtype=object)

# %%
#6.standardising the text format
df["employment_type"]=df["employment_type"].astype(str)
df["employment_type"]=df["employment_type"].str.strip()
df["employment_type"]=df["employment_type"].str.lower()
df["employment_type"]=df["employment_type"].str.title()

# %%
df["employment_type"].unique()
# Out:
# array(['Salaried', 'Self-Employed', 'Business', 'Contract'], dtype=object)

# %%
df.head()
# Out:
#   customer_id  age  monthly_income_ksh  employment_years  credit_score  \
# 0   CUST10001   23            101577.0              17.2         567.0
# 1   CUST10002   49            107972.0               4.1         732.0
# 2   CUST10003   55             41551.0               3.5         672.0
# 3   CUST10004   59             66605.0               7.8         732.0
# 4   CUST10005   38             46412.0               4.7         589.0
#
#    loan_amount_ksh  loan_term_months  existing_loans  late_payments_last_12m  \
# 0         128700.0                24               2                       0
# 1         109800.0                36               3                       1
# 2         245700.0                36               1                       0
# 3         159200.0                12               1                       5
# 4         178300.0                24               2                       0
#
#    debt_to_income_ratio  savings_ksh  dependents employment_type  \
# 0                  0.64      22900.0           5        Salaried
# 1                  0.38      31300.0           3        Salaried
# 2                  0.29     108400.0           4        Salaried
# 3                  0.18      45200.0           4        Salaried
# 4                  0.33      69900.0           3        Salaried
#
#   education_level housing_status  loan_default
# 0         Diploma           Rent             1
# 1          Degree         Family             1
# 2         Diploma            Own             0
# 3          Degree           Rent             1
# 4       Secondary         Family             1

# %%
#7.making sure the null in education_level is in the right format
df["education_level"]=df["education_level"].replace({'nan':np.nan})
df["education_level"].unique()
# Out:
# array(['Diploma', 'Degree', 'Secondary', 'Postgraduate', nan],
#       dtype=object)

# %%
#8.making sure the null in education_level is in the right format
df["housing_status"]=df["housing_status"].replace({'nan':np.nan})
df["housing_status"].unique()
# Out:
# array(['Rent', 'Family', 'Own', nan, 'rent '], dtype=object)

# %%
#9.changing the value into a float
df["savings_ksh"]=pd.to_numeric(df["savings_ksh"], errors="coerce")

# %%
#9.dropping duplicates again
df=df.drop_duplicates()

# %%
#10.resetting index
df=df.reset_index(drop=True)

# %%
#EDA
#1.How many customers defaulted versus those that didn't default
df["loan_default"].value_counts()
df["loan_default"].value_counts(normalize=True)*100
# Out:
# loan_default
# 1    62.680237
# 0    37.319763
# Name: proportion, dtype: float64

# %%
#looking at the numerical values
df.describe()
# Out:
#                age  monthly_income_ksh  employment_years  credit_score  \
# count  1179.000000         1156.000000       1162.000000   1179.000000
# mean     43.049194        66322.559689          7.364458    652.114504
# std      12.930503        31311.065354          4.653483     55.566870
# min      17.000000        13857.000000          0.000000    380.000000
# 25%      32.000000        44150.000000          3.800000    615.000000
# 50%      43.000000        59518.500000          7.350000    653.000000
# 75%      54.000000        82273.500000         10.700000    688.000000
# max      90.000000       287047.000000         24.400000    850.000000
#
#        loan_amount_ksh  loan_term_months  existing_loans  \
# count      1179.000000       1179.000000     1179.000000
# mean     183875.911790         22.106870        1.073791
# std       99246.034402         10.923664        1.027871
# min       33800.000000          6.000000        0.000000
# 25%      110500.000000         12.000000        0.000000
# 50%      165300.000000         24.000000        1.000000
# 75%      226600.000000         24.000000        2.000000
# max      782200.000000         48.000000        6.000000
#
#        late_payments_last_12m  debt_to_income_ratio   savings_ksh  \
# count             1179.000000           1179.000000  1.179000e+03
# mean                 0.865988              0.356633  1.089924e+05
# std                  0.959638              0.123048  1.127025e+05
# min                  0.000000              0.050000  8.700000e+03
# 25%                  0.000000              0.280000  4.985000e+04
# 50%                  1.000000              0.360000  8.070000e+04
# 75%                  1.000000              0.430000  1.363000e+05
# max                  5.000000              1.500000  2.380000e+06
#
#         dependents  loan_default
# count  1179.000000   1179.000000
# mean      2.473282      0.626802
# std       1.698373      0.483859
# min       0.000000      0.000000
# 25%       1.000000      0.000000
# 50%       3.000000      1.000000
# 75%       4.000000      1.000000
# max       5.000000      1.000000

# %%
#looking at categorical_values
#1.employment_type
df["employment_type"].value_counts()
# Out:
# employment_type
# Salaried         577
# Business         254
# Self-Employed    236
# Contract         112
# Name: count, dtype: int64

# %%
#2.education_level
df["education_level"].value_counts()
# Out:
# education_level
# Degree          511
# Diploma         327
# Secondary       218
# Postgraduate    105
# Name: count, dtype: int64

# %%
#3. housing_status
df["housing_status"].value_counts()
# Out:
# housing_status
# Rent      571
# Own       412
# Family    171
# rent        8
# Name: count, dtype: int64

# %%
#looking at the relationships between the target and some variables
#1.credit_score
df.groupby("loan_default")["credit_score"].mean()
# Out:
# loan_default
# 0    676.843182
# 1    637.391069
# Name: credit_score, dtype: float64

# %%
#2.Monthly_income_ksh
df.groupby("loan_default")["monthly_income_ksh"].mean()
# Out:
# loan_default
# 0    66529.823799
# 1    66196.586926
# Name: monthly_income_ksh, dtype: float64

# %%
#3.debt_to_income_ratio
df.groupby("loan_default")["debt_to_income_ratio"].mean()
# Out:
# loan_default
# 0    0.342818
# 1    0.364858
# Name: debt_to_income_ratio, dtype: float64

# %%
#4.late_payments_last_12m
df.groupby("loan_default")["late_payments_last_12m"].mean()
# Out:
# loan_default
# 0    0.522727
# 1    1.070365
# Name: late_payments_last_12m, dtype: float64

# %%
#Separate features and target
x=df.drop(columns= ["loan_default", "customer_id"]) #the feature
y=df["loan_default"]#target variable

# %%
#train-test split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# %%
#identify numerical and categorical variables
numerical_features = [
    "age",
    "monthly_income_ksh",
    "employment_years",
    "credit_score",
    "loan_amount_ksh",
    "loan_term_months",
    "existing_loans",
    "late_payments_last_12m",
    "debt_to_income_ratio",
    "savings_ksh",
    "dependents"
]

categorical_features = [
    "employment_type",
    "education_level",
    "housing_status"
]

# %%
#building the pre processing pipeline
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
#numerical_pipeline
numeric_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

# %%
#categorical pipeline
categorical_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(handle_unknown="ignore"))
])

# %%
#Combining both of them
preprocessor = ColumnTransformer([
    ("numeric", numeric_pipeline, numerical_features),
    ("categorical", categorical_pipeline, categorical_features)
])

# %%
#Training logistic regression
from sklearn.linear_model import LogisticRegression

logistic_model = Pipeline([
    ("preprocessor", preprocessor),
    ("model", LogisticRegression(max_iter=1000))
])

logistic_model.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numeric',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'monthly_income_ksh',
#                                                    'employment_years',
#                                                    'credit_score',
#                                                    'loan_amount_ksh',
#                                                    'loan_term_months',
#                                                    'existing_loans',
#                                                    'late_payments_last_12m',
#                                                    'debt_to_income_ratio',
#                                                    'savings_ksh',
#                                                    'dependents']),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['employment_type',
#                                                    'education_level',
#                                                    'housing_status'])])),
#                 ('model', LogisticRegression(max_iter=1000))])

# %%
#Making logistic_regression predictions
logistic_pred = logistic_model.predict(x_test)

# %%
#Evaluate logistic regression
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

print("Logistic Regression")
print("Accuracy:", accuracy_score(y_test, logistic_pred)) #What percentage of all predictions were correct?
print("Precision:", precision_score(y_test, logistic_pred)) #Of the customers predicted to default, how many actually defaulted?
print("Recall:", recall_score(y_test, logistic_pred)) #Of all customers who actually defaulted, how many did we identify?
print("F1 Score:", f1_score(y_test, logistic_pred)) #How well does the model balance precision and recall?
# Out:
# Logistic Regression
# Accuracy: 0.6779661016949152
# Precision: 0.7222222222222222
# Recall: 0.7905405405405406
# F1 Score: 0.7548387096774194

# %%
#training Random Forest
from sklearn.ensemble import RandomForestClassifier

random_forest = Pipeline([
    ("preprocessor", preprocessor),
    ("model", RandomForestClassifier(
        n_estimators=100,
        random_state=42
    ))
])

random_forest.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numeric',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'monthly_income_ksh',
#                                                    'employment_years',
#                                                    'credit_score',
#                                                    'loan_amount_ksh',
#                                                    'loan_term_months',
#                                                    'existing_loans',
#                                                    'late_payments_last_12m',
#                                                    'debt_to_income_ratio',
#                                                    'savings_ksh',
#                                                    'dependents']),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['employment_type',
#                                                    'education_level',
#                                                    'housing_status'])])),
#                 ('model', RandomForestClassifier(random_state=42))])

# %%
#Make Random Forest Predictions
forest_pred = random_forest.predict(x_test)

# %%
#evaluate Random Forest
print("Random Forest")
print("Accuracy:", accuracy_score(y_test, forest_pred))
print("Precision:", precision_score(y_test, forest_pred))
print("Recall:", recall_score(y_test, forest_pred))
print("F1 Score:", f1_score(y_test, forest_pred))
# Out:
# Random Forest
# Accuracy: 0.7076271186440678
# Precision: 0.7453416149068323
# Recall: 0.8108108108108109
# F1 Score: 0.7766990291262136

# %%
#Compare the two models
results = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Random Forest"
    ],

    "Accuracy": [
        accuracy_score(y_test, logistic_pred),
        accuracy_score(y_test, forest_pred)
    ],

    "Precision": [
        precision_score(y_test, logistic_pred),
        precision_score(y_test, forest_pred)
    ],

    "Recall": [
        recall_score(y_test, logistic_pred),
        recall_score(y_test, forest_pred)
    ],

    "F1 Score": [
        f1_score(y_test, logistic_pred),
        f1_score(y_test, forest_pred)
    ]
})

results
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score
# 0  Logistic Regression  0.677966   0.722222  0.790541  0.754839
# 1        Random Forest  0.707627   0.745342  0.810811  0.776699

# %%
#confusion matrices
#Shows exactly what my model got right and wrong
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

ConfusionMatrixDisplay.from_predictions(
    y_test,
    logistic_pred
)

plt.title("Logistic Regression Confusion Matrix")
plt.show()
ConfusionMatrixDisplay.from_predictions(
    y_test,
    forest_pred
)

plt.title("Random Forest Confusion Matrix")
plt.show()

# %%
#Cross validation- testing how consistently they perform
from sklearn.model_selection import cross_val_score

logistic_cv = cross_val_score(
    logistic_model,
    x_train,
    y_train,
    cv=5,
    scoring="f1"
)

forest_cv = cross_val_score(
    random_forest,
    x_train,
    y_train,
    cv=5,
    scoring="f1"
)

print("Logistic Regression CV F1 scores:")
print(logistic_cv)

print("Mean:", logistic_cv.mean())

print("\nRandom Forest CV F1 scores:")
print(forest_cv)

print("Mean:", forest_cv.mean())
# Out:
# Logistic Regression CV F1 scores:
# [0.8        0.80645161 0.8        0.8046875  0.76984127]
# Mean: 0.7961960765488991
#
# Random Forest CV F1 scores:
# [0.75502008 0.808      0.78599222 0.79069767 0.77470356]
# Mean: 0.782882705990195

# %%
#hyperparameter tuning
#imporoving the Random Forest
from sklearn.model_selection import GridSearchCV

param_grid = {
    "model__n_estimators": [50, 100, 200],
    "model__max_depth": [5, 10, 15, None],
    "model__min_samples_split": [2, 5, 10]
}
grid_search = GridSearchCV(
    estimator=random_forest,
    param_grid=param_grid,
    cv=5,
    scoring="f1",
    n_jobs=-1
)

grid_search.fit(x_train, y_train)
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'model__max_depth': 5, 'model__min_samples_split': 10, 'model__n_estimators': 200}
# 0.798494237982226

# %%
#Getting my final model
best_model = grid_search.best_estimator_
final_pred = best_model.predict(x_test)
print("Final Model Performance")

print("Accuracy:",
      accuracy_score(y_test, final_pred))

print("Precision:",
      precision_score(y_test, final_pred))

print("Recall:",
      recall_score(y_test, final_pred))

print("F1 Score:",
      f1_score(y_test, final_pred))
# Out:
# Final Model Performance
# Accuracy: 0.6694915254237288
# Precision: 0.6944444444444444
# Recall: 0.8445945945945946
# F1 Score: 0.7621951219512195

# %%
#final confusion matrix
ConfusionMatrixDisplay.from_predictions(
    y_test,
    final_pred
)

plt.title("Final Random Forest Confusion Matrix")
plt.show()

# %%
#Calculate your final metrics
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report
)

print("Final Model Performance")
print("-----------------------")

print("Accuracy:", accuracy_score(y_test, final_pred))
print("Precision:", precision_score(y_test, final_pred))
print("Recall:", recall_score(y_test, final_pred))
print("F1 Score:", f1_score(y_test, final_pred))

print("\nClassification Report:")
print(classification_report(y_test, final_pred))
# Out:
# Final Model Performance
# -----------------------
# Accuracy: 0.6694915254237288
# Precision: 0.6944444444444444
# Recall: 0.8445945945945946
# F1 Score: 0.7621951219512195
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.59      0.38      0.46        88
#            1       0.69      0.84      0.76       148
#
#     accuracy                           0.67       236
#    macro avg       0.64      0.61      0.61       236
# weighted avg       0.66      0.67      0.65       236

# %%
#Calculate ROC-AUC
from sklearn.metrics import roc_auc_score

final_prob = best_model.predict_proba(x_test)[:, 1]

roc_auc = roc_auc_score(y_test, final_prob)

print("Final ROC-AUC:", roc_auc)
# Out:
# Final ROC-AUC: 0.7248925061425061

# %%
#Plot ROC curve
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_predictions(
    y_test,
    final_prob
)

plt.title("Final Random Forest ROC Curve")
plt.show()

# %%
#Look at feature importance
# Get the trained Random Forest
rf_model = best_model.named_steps["model"]

# Get the preprocessing step
preprocessor_fitted = best_model.named_steps["preprocessor"]

# Get feature names after preprocessing
feature_names = preprocessor_fitted.get_feature_names_out()

# Get feature importance
importance = rf_model.feature_importances_

feature_importance = pd.DataFrame({
    "Feature": feature_names,
    "Importance": importance
})

feature_importance = feature_importance.sort_values(
    by="Importance",
    ascending=False
)

feature_importance.head(15)
# Out:
#                                    Feature  Importance
# 3                    numeric__credit_score    0.329714
# 7          numeric__late_payments_last_12m    0.178521
# 4                 numeric__loan_amount_ksh    0.071249
# 9                     numeric__savings_ksh    0.068897
# 8            numeric__debt_to_income_ratio    0.065649
# 0                             numeric__age    0.061671
# 1              numeric__monthly_income_ksh    0.056427
# 2                numeric__employment_years    0.047740
# 6                  numeric__existing_loans    0.020328
# 5                numeric__loan_term_months    0.020070
# 10                     numeric__dependents    0.013189
# 18  categorical__education_level_Secondary    0.008501
# 20         categorical__housing_status_Own    0.008241
# 13   categorical__employment_type_Salaried    0.007051
# 15     categorical__education_level_Degree    0.006688

# %%
#visualization of feature importance
feature_importance.head(10).plot(
    x="Feature",
    y="Importance",
    kind="barh",
    figsize=(10, 6)
)

plt.title("Top 10 Features - Random Forest")
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.gca().invert_yaxis()
plt.show()
